# %%
print("hello world, abeokuta i am learning python!")
# Out:
# hello world, abeokuta i am learning python!

# %%
name =input("Enter your name ? : ")

print(f"welcome to python {name} !")
# Out:
# welcome to python john okonmah snr !
